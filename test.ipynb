# %%
from datasets import load_dataset

ds = load_dataset("foursquare/fsq-os-places", "places")

# %% [markdown]
# Set your Hugging Face token in an environment variable before running the load cell.

# %%
import pandas as pd

pd.set_option("display.max_rows", None)

df_au = df[df["country"] == "AU"]
df_au
